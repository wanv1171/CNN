# %%
import tensorflow as tf
import numpy as np
import pickle
import os

# %% [markdown]
# Getting the Data
# ------

# %%
CIFAR_DIR = 'C:/Users/brian/Desktop/TensorFlow/cifar-10-batches-py'

def load_data(filename):
    """ READ DATA FROM BATCH FILES """
    with open(filename, "rb") as file:
        data = pickle.load(file, encoding="bytes")

        d_decoded = {}
        for k, v in data.items():
            d_decoded[k.decode('utf8')] = v

        data = d_decoded

    return(data['data'], data['labels'])

class CifarData:
    def __init__(self, filenames, need_shuffle):
        all_data = []
        all_labels = []

        for filename in filenames:
            data, labels = load_data(filename)
            for item, label in zip(data, labels):
                all_data.append(item)
                all_labels.append(label)
                
        self._data = np.vstack(all_data)
        self._data = self._data / 127.5 - 1
        self._labels = np.hstack(all_labels)
        self._num_examples = self._data.shape[0]
        self._need_shuffle = need_shuffle
        self._indicator = 0

        if(self._need_shuffle):
            self.shuffle_data()

    def shuffle_data(self):
        p = np.random.permutation(self._num_examples)
        self._data = self._data[p]
        self._labels = self._labels[p]

    def next_batch(self, batch_size):
        end_indicator = self._indicator + batch_size

        if(end_indicator > self._num_examples):
            if (self._need_shuffle):
                self.shuffle_data()
                self._indicator = 0
                end_indicator = batch_size
            else:
                raise Exception("no more data")
        
        if (end_indicator > self._num_examples):
            raise Exception("Batch Size Too Large")

        batch_data = self._data[self._indicator: end_indicator]
        batch_labels = self._labels[self._indicator: end_indicator]

        self._indicator = end_indicator
        return(batch_data, batch_labels)

# %%
train_filenames = [os.path.join(CIFAR_DIR,'data_batch_%d' % i) for i in range(1, 6)]
test_filenames = [os.path.join(CIFAR_DIR, 'test_batch')]

train_data = CifarData(train_filenames, True)
test_data = CifarData(test_filenames, False)

# %% [markdown]
# Getting the Model
# ------

# %% [markdown]
# ### Residual

# %%
def inception_block(x, output_channel, name):
    with tf.variable_scope(name):
        conv1_1 = tf.layers.conv2d(x, output_channel[0], (1, 1), strides = (1, 1), padding="SAME", 
                                   activation = tf.nn.relu, name = "conv1_1")
        
        conv3_3 = tf.layers.conv2d(x, output_channel[1], (3, 3), strides = (1, 1), padding="SAME", 
                                   activation = tf.nn.relu, name = "conv3_3")
        
        conv5_5 = tf.layers.conv2d(x, output_channel[2], (5, 5), strides = (1, 1), padding="SAME", 
                                   activation = tf.nn.relu, name = "conv5_5")
        
        max_pooling = tf.layers.max_pooling2d(x, (2, 2), (2, 2), name="max_pooling")
        
        max_pooling_shape = max_pooling.get_shape().as_list()[1:]
        
        # shape [None: Width: Height: Channels]
        
        x_shape = x.get_shape().as_list()[1:]
        
        width_padding = (x_shape[0] - max_pooling_shape[0]) // 2
        height_padding = (x_shape[1] - max_pooling_shape[1]) // 2
        
        padded_pooling = tf.pad(max_pooling, 
                                [[0, 0], 
                                 [width_padding, width_padding],
                                 [height_padding, height_padding], 
                                 [0, 0]])
        
        concat_layer = tf.concat([conv1_1, conv3_3, conv5_5, padded_pooling], axis = 3)
        
        return(concat_layer)

# %%
# [None: 3072]
x = tf.placeholder(tf.float32, [None, 3072]) 
y = tf.placeholder(tf.int64, [None])

# [None: 3: 32: 32]
x_image = tf.reshape(x, [-1, 3, 32, 32])
# [None: 32: 32: 3]
x_image = tf.transpose(x_image, perm=[0, 2, 3, 1])


conv1 = tf.layers.conv2d(x_image, 32, (3, 3), padding="same", activation=tf.nn.relu, name="conv1")
# [None: 16: 16: 32]
pooling1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), name="pooling1")

inception_2a = inception_block(pooling1, [16, 16, 16], name="inception_2a")

inception_2b = inception_block(inception_2a, [16, 16, 16], name="inception_2b")

pooling2 = tf.layers.max_pooling2d(inception_2b, (2,2), (2,2), name="pooling2")

inception_3a = inception_block(pooling2, [16, 16, 16], name="inception_3a")

inception_3b = inception_block(inception_3a, [16, 16, 16], name="inception_3b")

pooling3 = tf.layers.max_pooling2d(inception_3b, (2,2), (2,2), name="pooling3")

flatten_pooling3 = tf.layers.flatten(pooling3)

y_ = tf.layers.dense(flatten_pooling3, 10)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1627   try:
# -> 1628     c_op = c_api.TF_FinishOperation(op_desc)
#    1629   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Shapes must be equal rank, but are 4 and 1
# 	From merging shape 2 with other shapes. for 'inception_2a/Pad/paddings_1' (op: 'Pack') with input shapes: [2], [2,8,8,32], [2,8,8,32], [2].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     509                 as_ref=input_arg.is_ref,
# --> 510                 preferred_dtype=default_dtype)
#     511           except TypeError as err:
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1145     if ret is None:
# -> 1146       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1147
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_conversion_function(v, dtype, name, as_ref)
#     970     v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# --> 971   return _autopacking_helper(v, dtype, name or "packed")
#     972
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_helper(list_or_tuple, dtype, name)
#     922               constant_op.constant(elem, dtype=dtype, name=str(i)))
# --> 923       return gen_array_ops.pack(elems_as_tensors, name=scope)
#     924     else:
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in pack(values, axis, name)
#    4873     _, _, _op = _op_def_lib._apply_op_helper(
# -> 4874         "Pack", values=values, axis=axis, name=name)
#    4875     _result = _op.outputs[:]
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3273           original_op=self._default_original_op,
# -> 3274           op_def=op_def)
#    3275       self._create_op_helper(ret, compute_device=compute_device)
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1791       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1792                                 control_input_ops)
#    1793
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1630     # Convert to ValueError for backwards compatibility.
# -> 1631     raise ValueError(str(e))
#    1632
#
# ValueError: Shapes must be equal rank, but are 4 and 1
# 	From merging shape 2 with other shapes. for 'inception_2a/Pad/paddings_1' (op: 'Pack') with input shapes: [2], [2,8,8,32], [2,8,8,32], [2].
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1627   try:
# -> 1628     c_op = c_api.TF_FinishOperation(op_desc)
#    1629   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Shapes must be equal rank, but are 4 and 1
# 	From merging shape 2 with other shapes. for 'inception_2a/Pad/packed' (op: 'Pack') with input shapes: [2], [2,8,8,32], [2,8,8,32], [2].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     523               observed = ops.internal_convert_to_tensor(
# --> 524                   values, as_ref=input_arg.is_ref).dtype.name
#     525             except ValueError as err:
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1145     if ret is None:
# -> 1146       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1147
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_conversion_function(v, dtype, name, as_ref)
#     970     v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# --> 971   return _autopacking_helper(v, dtype, name or "packed")
#     972
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_helper(list_or_tuple, dtype, name)
#     922               constant_op.constant(elem, dtype=dtype, name=str(i)))
# --> 923       return gen_array_ops.pack(elems_as_tensors, name=scope)
#     924     else:
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in pack(values, axis, name)
#    4873     _, _, _op = _op_def_lib._apply_op_helper(
# -> 4874         "Pack", values=values, axis=axis, name=name)
#    4875     _result = _op.outputs[:]
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3273           original_op=self._default_original_op,
# -> 3274           op_def=op_def)
#    3275       self._create_op_helper(ret, compute_device=compute_device)
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1791       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1792                                 control_input_ops)
#    1793
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1630     # Convert to ValueError for backwards compatibility.
# -> 1631     raise ValueError(str(e))
#    1632
#
# ValueError: Shapes must be equal rank, but are 4 and 1
# 	From merging shape 2 with other shapes. for 'inception_2a/Pad/packed' (op: 'Pack') with input shapes: [2], [2,8,8,32], [2,8,8,32], [2].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-851d0bcb74a9> in <module>
#      13 pooling1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), name="pooling1")
#      14
# ---> 15 inception_2a = inception_block(pooling1, [16, 16, 16], name="inception_2a")
#      16
#      17 inception_2b = inception_block(inception_2a, [16, 16, 16], name="inception_2b")
#
# <ipython-input-4-d2ae992f098e> in inception_block(x, output_channel, name)
#      25                                  [width_padding, width_padding],
#      26                                  [height_padding, height_padding],
# ---> 27                                  [0, 0]])
#      28
#      29         concat_layer = tf.concat([conv1_1, conv3_3, conv5_5, padded_pooling], axis = 3)
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\array_ops.py in pad(tensor, paddings, mode, name, constant_values)
#    1893           tensor, paddings, constant_values, name=name)
#    1894     else:
# -> 1895       result = gen_array_ops.pad(tensor, paddings, name=name)
#    1896   elif mode == "REFLECT":
#    1897     result = gen_array_ops.mirror_pad(
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in pad(input, paddings, name)
#    4960   if _ctx is None or not _ctx._eager_context.is_eager:
#    4961     _, _, _op = _op_def_lib._apply_op_helper(
# -> 4962         "Pad", input=input, paddings=paddings, name=name)
#    4963     _result = _op.outputs[:]
#    4964     _inputs_flat = _op.inputs
#
# D:\Programs\Anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     526               raise ValueError(
#     527                   "Tried to convert '%s' to a tensor and failed. Error: %s" %
# --> 528                   (input_name, err))
#     529             prefix = ("Input '%s' of '%s' Op has type %s that does not match" %
#     530                       (input_name, op_type_name, observed))
#
# ValueError: Tried to convert 'paddings' to a tensor and failed. Error: Shapes must be equal rank, but are 4 and 1
# 	From merging shape 2 with other shapes. for 'inception_2a/Pad/packed' (op: 'Pack') with input shapes: [2], [2,8,8,32], [2,8,8,32], [2].

# %% [markdown]
# ### Defining Loss Function and Optimizer

# %%
loss = tf.losses.sparse_softmax_cross_entropy(labels = y, logits = y_)

predict = tf.argmax(y_, 1)
correct_prediction = tf.equal(predict, y)

accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float64))

with tf.name_scope('train_op'):
    train_op = tf.train.AdamOptimizer(1e-3).minimize(loss)

init = tf.global_variables_initializer()

# %% [markdown]
# ### Define Global Train/Test Steps and Start the Model

# %%
batch_size = 20
train_steps = 10000

test_steps = 200

with tf.Session() as sess:
    sess.run(init)
    for i in range(train_steps):
        batch_data, batch_labels = train_data.next_batch(batch_size)
        loss_val, accu_val, _ = sess.run(
            [loss, accuracy, train_op], 
            feed_dict={
                x: batch_data, 
                y: batch_labels})

        if (i+1) % 100 == 0:
            print('[Train] Step: %d, loss: %4.5f, acc: %4.5f' \
                % (i+1, loss_val, accu_val))

        if (i+1) % 1000 == 0:
            test_data = CifarData(test_filenames, False)
            all_test_acc_val = [] 

            for j in range(test_steps):
                test_batch_data, test_batch_labels = test_data.next_batch(batch_size)
                test_acc_val = sess.run(
                    [accuracy],
                    feed_dict = {
                        x: test_batch_data, 
                        y: test_batch_labels
                })

                all_test_acc_val.append(test_acc_val)   

            test_acc = np.mean(all_test_acc_val)

            print('[Test] Step: %d, Overall Acc: %4.5f' % (i+1, test_acc))
